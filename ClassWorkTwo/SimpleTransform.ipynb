# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
from scipy import ndimage
# %matplotlib inline

# %%
pic=plt.imread('./source/picture1.jpg')

# %%
plt.imshow(pic)

# %%
#移动操作
plt.imshow(ndimage.shift(pic,shift=[-100,100,0]))

# %%
#上下镜像颠倒
plt.imshow(pic[::-1])

# %%
#左右镜像颠倒
plt.imshow(pic[:,::-1])

# %%
#旋转操作
plt.imshow(ndimage.rotate(pic,angle=45))

# %%
plt.imshow(ndimage.zoom(pic,zoom=[0.1,0.1,1.0]))

# %%
#组合操作
move=ndimage.shift(pic,shift=[-100,100,0])
rotate=ndimage.rotate(move,angle=45)
mirror=rotate[:,::-1]
plt.im
